# %% [markdown]
# <a href="https://colab.research.google.com/github/anupamav/NVS-GAN/blob/main/NVS_test_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/NovelViewSynthesis
# Out:
# /content/drive/MyDrive/NovelViewSynthesis

# %%
# %load_ext autoreload
# %autoreload 2
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
pip install tfa-nightly
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 620.3/620.3 kB 9.3 MB/s eta 0:00:00
# ...

# %%
from main import *

# %%
#test_single_model("configs/config_examples/test_config_chair_pg")

# %%
test_and_export_picture_for_single_model("configs/config_examples/export_image_car_chair")
# Out:
# start to load dataset
# dataset loading finished
# [[0, 0, 0, 1, 0], [0, 0, 0, 2, 0]]
# 123
# model constructed!
# model_data/ModelsListForTest/ResNet50Chair.h5
# loaded path
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  image_input (InputLayer)    [(None, 256, 256, 3)]        0         []
#
#  lambda_1 (Lambda)           (None, 256, 256, 3)          0         ['image_input[0][0]']
#
#  resnet50 (Functional)       (None, 8, 8, 2048)           2358771   ['lambda_1[0][0]']
#                                                           2
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 1024)           1887539   ['resnet50[0][0]']
#                                                           2
#
#  viewpoint_input (InputLaye  [(None, 18)]                 0         []
#  r)
#
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Replace 'your_image.png' with the path to your image file
image_path = '/content/drive/MyDrive/NovelViewSynthesis/test_result/chair_trail/zhou16attention_u_net_20240309_052541.png'

# Load the image
img = mpimg.imread(image_path)

# Display the image
plt.imshow(img)
plt.axis('off')  # Turn off axis numbers
plt.show()
